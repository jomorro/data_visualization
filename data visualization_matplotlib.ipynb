# %%
#import library
import matplotlib.pyplot as plt
#plot lines 
x, y = [ 1600, 1700, 1800, 1900, 2000 ] , [ 0.2, 0.5, 1.1, 2.2, 7.7 ]
#creates lines
plt.plot(x, y)
plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population (billions)")
plt.show()

# %%
pyplot as plt
# Out:
#   File "/tmp/ipykernel_92155/3691164532.py", line 1
#     pyplot as plt
#             ^
# SyntaxError: invalid syntax

# %%
#import library
import matplotlib.pyplot as plt
#plot lines 
x1, y1 = [ 1600, 1700, 1800, 1900, 2000 ] , [ 0.2, 0.5, 1.1, 2.2, 7.7 ]
x2, y2 = [ 1600, 1700, 1800, 1900, 2000 ] , [ 1, 1, 2, 3, 4 ]
#creates red lines with x dots
plt.plot(x1, y1,'rx-', label='Actual')

#creates blue lines with circle dots
plt.plot(x2, y2, 'bo--', label='Fake')

plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population (billions)")
plt.show()

# %%
#bar plot,creating x and y plot 
num_people, categories = [ 4, 8, 3, 6, 2 ] , [ "Comedy", "Action", "Thriller", "Romance", "Horror" ] 
plt.bar(categories, num_people)
plt.title("Favorite Movie Category", fontsize=24)
plt.xlabel("Category", fontsize=16)
plt.ylabel("# of People", fontsize=16)
plt.xticks(fontname="Fantasy")
plt.yticks(fontname="Fantasy")
plt.show()

# %%
#creating box plot
males, females = [ 72, 68, 65, 77, 73, 71, 69 ] , [ 60, 65, 68, 61, 63, 64 ]
heights = [ males, females ]
plt.figure(figsize=(15, 8))
plt.boxplot(heights)
#set number of x ticks
plt.xticks( [1, 2 ], ["Male", "Female " ])
plt.title("Height by Gender", fontsize=22)
plt.ylabel("Height (inches)", fontsize=14)
plt.xlabel("Gender", fontsize=14)
plt.show()

# %%
#creating scatter plot representing height-weight distribution
import random
random.seed(2)
height = [ randint(58, 78) for x in range(20) ] #20 records between 4' 10" and 6'6"
weight = [ randint(90, 250) for x in range(20) ] #20 records between 90lbs and 250lbs

plt.scatter(weight, height)
plt.title("Height-Weight Distribution")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (inches)")
plt.show()

# %%
#histogram
import numpy as np
np.random.seed(5)
ages = [ np.random.normal(loc=40, scale=10) for x in range(1000) ] #age distribution around 40
plt.hist(ages, bins=45) #bins is the number of bars
plt.title("Ages per Population")
plt.xlabel("Age")
plt.ylabel("# of People")
plt.show()

# %%
#histogram distribution 
import numpy as np
#showing the importance of histogram's display central distribution
florida = [ np.random.normal(loc=60, scale=15) for x in range(1000) ]
california = [ np.random.normal(loc=35, scale=5) for x in range(1000) ]

#chart1
plt.hist(florida, bins=45, color='r', alpha=0.4) #alpha is the opacity, making it see through

plt.show()

#chart2
plt.hist(california, bins=45, color='b', alpha=0.4)

plt.show()

#chart3
plt.hist(florida, bins=45, color='r', alpha=0.4)


plt.hist(california, bins=45, color='b', alpha=0.4)
plt.show()

# %%
#saving charts in data visualization
#savefig method to save charts as a jpg to local folder
x, y = [ 1600, 1700, 1800, 1900, 2000 ] , [ 0.2, 0.5, 1.1, 2.2, 7.7]
plt.plot(x, y, 'bo-') #creates blue solid line with circle dots
plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population (billions)")
plt.savefig("population.jpg")

# %%
#creating scatter plot with height-weight distribution
import random
random.seed(2)
height = [ randint(58, 78) for x in range(20) ]
weight = [ randint(90, 250) for x in range(20) ]
age = [ randint(18, 65) for x in range(20) ] #20 records 

plt.scatter(weight, height, c=age) #sets the age list to be shown by color

plt.title("Height-Weight Distribution")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (inches)")
plt.colorbar(label="Age")
plt.show()
